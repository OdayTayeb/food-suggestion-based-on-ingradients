# %%
from experta import *

# %%
class Eng(KnowledgeEngine):
    # Rate Function
    def RATE(self,*arg):
        sz1 = int(arg[0])
        sz2 = int(arg[1])
        x=0
        for i in range(2,2+sz1):
            x = x + arg[i]    
        y=0
        for i in range(2+sz1,2+sz1+sz2):
            y = y + arg[i]
        x = x / sz1
        y = y / sz2
        x = x * 3
        return (x+y)/4

    # Rule to read user Ingredients and Quantities   
    @Rule(NOT(Fact('IngredientEntered')),Fact(question0='main food'))
    def EnterIngredients(self):
        print('**********************************************Ingredients**********************************************************')
        print('rez , pazzela , fool , lahem_naem , lahem_sheaf , adas , basal , rez_kabseh , dajaj , fahem , sheairia , fasolia , ')
        print('debes_banadora , pamia , batata , homos , sheesh , osfor , laban , kosa , zeat , mlokhia , spanikh , lahem_kabab , ')
        print('zahra , bethengan , banadora , fasolia_hab , hamed , borgul , lahem_habra , dehneh , malfof , warak_enab , shawarma , ')
        print('lahem_sharhat , taheen , bead , zaytoon , jebneh , lahem_burger , makarona ,spaghetti , bashamel , seleq , lobia , ')
        print('jazar , keshek , bakdones , amaa_kharoof , akdam_kharoof , samneh , khabez_maali , khas , jebneh_shedar , mayonez , mokhalal')
        print('Enter Ingredients and their portions , type finish when you are done \n')
        while True:
            ingredient = input('Enter Ingredient Name : ')
            if ingredient == "finish":
                break
            quantity = input('Enter quantity : ')
            f = Fact()
            f[ingredient] = quantity
            self.declare(f)    
        self.declare(Fact(availabletime = input('how many minutes do you have? ')))    
        self.declare(Fact('IngredientEntered'))
    
    @Rule(NOT(Fact('dessert_ingredients_entered')),Fact(question0='dessert'))
    def enter_dessert_ingredients(self):
        print('**********************************************Ingredients**********************************************************')
        print('bead, baskot, ')
        print('creama\n')
        print('jebneh_mozarella, joz_hend, ')
        print('haleeb\n')
        print('kakao, kahwe, kenafa\n')
        print('laban, ')
        print('mraba, mokasarat\n')
        print('nasle, nashaa, ')
        print('qater, qashta\n')
        print('rez, ')
        print('sokar, sameed, samneh\n')
        print('taheen, ')
        print('vanilla, ')
        print('zaet, zebdeh\n')
       
        while True:
            ingredient = input('Enter Ingredient Name : ')
            if ingredient == "finish":
                break
            quantity = input('Enter quantity : ')
            f = Fact()
            f[ingredient] = quantity
            self.declare(f)    
        self.declare(Fact(availabletime = input('how many minutes do you have? ')))    
        self.declare(Fact('dessert_ingredients_entered'))
    
    
        
    # Rules to add Not Entered Ingredients with 0 quantity    
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(rez = W())),salience=10)
    def rez_Enter(self):
        self.declare(Fact(rez = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(pazzela = W())),salience=10)
    def pazzela_Enter(self):
        self.declare(Fact(pazzela = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(fool = W())),salience=10)
    def fool_Enter(self):
        self.declare(Fact(fool = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_naem = W())),salience=10)
    def lahem_naem_Enter(self):
        self.declare(Fact(lahem_naem = '0'))
   
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_sheaf = W())),salience=10)
    def lahem_sheaf_Enter(self):
        self.declare(Fact(lahem_sheaf = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(adas = W())),salience=10)
    def adas_Enter(self):
        self.declare(Fact(adas = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(basal = W())),salience=10)
    def basal_Enter(self):
        self.declare(Fact(basal = '0'))  
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(kabseh_rez = W())),salience=10)
    def kabseh_rez_Enter(self):
        self.declare(Fact(kabseh_rez = '0'))  
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(dajaj = W())),salience=10)
    def dajaj_Enter(self):
        self.declare(Fact(dajaj = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(fahem = W())),salience=10)
    def fahem_Enter(self):
        self.declare(Fact(fahem = '0'))    
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(shaieria = W())),salience=10)
    def shaieria_Enter(self):
        self.declare(Fact(shaieria = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(fasolia = W())),salience=10)
    def fasolia_Enter(self):
        self.declare(Fact(fasolia = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(debes_banadora = W())),salience=10)
    def debes_banadora_Enter(self):
        self.declare(Fact(debes_banadora = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(pamia = W())),salience=10)
    def pamia_Enter(self):
        self.declare(Fact(pamia = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(batata = W())),salience=10)
    def batata_Enter(self):
        self.declare(Fact(batata = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(homos = W())),salience=10)
    def homos_Enter(self):
        self.declare(Fact(homos = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(sheesh = W())),salience=10)
    def sheesh_Enter(self):
        self.declare(Fact(sheesh = '0'))
   
    @Rule(Fact('IngredientEntered'),NOT(Fact(osfor = W())),salience=10)
    def osfor_Enter(self):
        self.declare(Fact(osfor = '0'))
    
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(laban = W())),salience=10)
    def laban_Enter(self):
        self.declare(Fact(laban = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(kosa = W())),salience=10)
    def kosa_Enter(self):
        self.declare(Fact(kosa = '0'))
    
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(zaet = W())),salience=10)
    def zaet_Enter(self):
        self.declare(Fact(zaet = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(mlokhia = W())),salience=10)
    def mlokhia_Enter(self):
        self.declare(Fact(mlokhia = '0')) 
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(spanikh = W())),salience=10)
    def spanikh_Enter(self):
        self.declare(Fact(spanikh = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_kabab = W())),salience=10)
    def lahem_kabab_Enter(self):
        self.declare(Fact(lahem_kabab = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(zahra = W())),salience=10)
    def zahra_Enter(self):
        self.declare(Fact(zahra = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(bathengan = W())),salience=10)
    def bathengan_Enter(self):
        self.declare(Fact(bathengan = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(banadora = W())),salience=10)
    def banadora_Enter(self):
        self.declare(Fact(banadora = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(fasolia_hab = W())),salience=10)
    def fasolia_hab_Enter(self):
        self.declare(Fact(fasolia_hab = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(hamed = W())),salience=10)
    def hamed_Enter(self):
        self.declare(Fact(hamed = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(borgul = W())),salience=10)
    def borgul_Enter(self):
        self.declare(Fact(borgul = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_habra = W())),salience=10)
    def lahem_habra_Enter(self):
        self.declare(Fact(lahem_habra = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(dehnah = W())),salience=10)
    def dehnah_Enter(self):
        self.declare(Fact(dehnah = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(malfof = W())),salience=10)
    def malfof_Enter(self):
        self.declare(Fact(malfof = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(warak_enab = W())),salience=10)
    def warak_enab_Enter(self):
        self.declare(Fact(warak_enab = '0'))
        
    #
    @Rule(Fact('IngredientEntered'),NOT(Fact(shawarma = W())),salience=10)
    def shawarma_Enter(self):
        self.declare(Fact(shawarma = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_sharhat = W())),salience=10)
    def lahem_sharhat_Enter(self):
        self.declare(Fact(lahem_sharhat = '0'))    
        
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(taheen = W())),salience=10)
    def taheen_Enter(self):
        self.declare(Fact(taheen = '0'))
        
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(bead = W())),salience=10)
    def bead_Enter(self):
        self.declare(Fact(bead = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(zaytoon = W())),salience=10)
    def zaytoon_Enter(self):
        self.declare(Fact(zaytoon = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(jebneh = W())),salience=10)
    def jebneh_Enter(self):
        self.declare(Fact(jebneh = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(lahem_burger = W())),salience=10)
    def lahem_burger_Enter(self):
        self.declare(Fact(lahem_burger = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(makarona = W())),salience=10)
    def makarona_Enter(self):
        self.declare(Fact(makarona = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(spaghetti = W())),salience=10)
    def spaghetti_Enter(self):
        self.declare(Fact(spaghetti = '0'))
   
    @Rule(Fact('IngredientEntered'),NOT(Fact(bashamel = W())),salience=10)
    def bashamel_Enter(self):
        self.declare(Fact(bashamel = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(seleq = W())),salience=10)
    def seleq_Enter(self):
        self.declare(Fact(seleq = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(lobia = W())),salience=10)
    def lobia_Enter(self):
        self.declare(Fact(lobia = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(jazar = W())),salience=10)
    def jazar_Enter(self):
        self.declare(Fact(jazar = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(keshek = W())),salience=10)
    def keshek_Enter(self):
        self.declare(Fact(keshek = '0')) 
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(bakdones = W())),salience=10)
    def bakdones_Enter(self):
        self.declare(Fact(bakdones = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(kharof_amaa = W())),salience=10)
    def kharof_amaa_Enter(self):
        self.declare(Fact(kharof_amaa = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(kharof_feet = W())),salience=10)
    def kharof_feet_Enter(self):
        self.declare(Fact(kharof_feet = '0'))
        
    
    @Rule(OR(Fact('IngredientEntered'),Fact('dessert_ingredients_entered')),NOT(Fact(semnah = W())),salience=10)
    def semnah_Enter(self):
        self.declare(Fact(semnah = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(khabez_maali = W())),salience=10)
    def khabez_maali_Enter(self):
        self.declare(Fact(khabez_maali = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(khas = W())),salience=10)
    def khas_Enter(self):
        self.declare(Fact(khas = '0'))
        
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(jebneh_shedar = W())),salience=10)
    def jebneh_shedar_Enter(self):
        self.declare(Fact(jebneh_shedar = '0'))
    
    @Rule(Fact('IngredientEntered'),NOT(Fact(mayonez = W())),salience=10)
    def mayonez_Enter(self):
        self.declare(Fact(mayonez = '0'))
        
    @Rule(Fact('IngredientEntered'),NOT(Fact(mokhalal = W())),salience=10)
    def mokhalal_Enter(self):
        self.declare(Fact(mokhalal = '0')) 
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(sokar = W())),salience=10)
    def sokar_Enter(self):
        self.declare(Fact(sokar = '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(sameed = W())),salience=10)
    def sameed_Enter(self):
        self.declare(Fact(sameed = '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(joz_hend = W())),salience=10)
    def joz_hend_Enter(self):
        self.declare(Fact(joz_hend = '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(mokasarat= W())),salience=10)
    def mokasarat_Enter(self):
        self.declare(Fact(mokasarat = '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(haleeb= W())),salience=10)
    def haleeb_Enter(self):
        self.declare(Fact(haleeb = '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(nashaa= W())),salience=10)
    def nashaa_Enter(self):
        self.declare(Fact(nashaa= '0'))
    
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(kenafa= W())),salience=10)
    def kenafa_Enter(self):
        self.declare(Fact(kenafa= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(qater= W())),salience=10)
    def qater_Enter(self):
        self.declare(Fact(qater= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(creama= W())),salience=10)
    def creama_Enter(self):
        self.declare(Fact(creama= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(jebneh_mozarella= W())),salience=10)
    def jebneh_mozarella_Enter(self):
        self.declare(Fact(jebneh_mozarella= '0'))
    
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(qashta= W())),salience=10)
    def qashta_Enter(self):
        self.declare(Fact(qashta= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(kakao= W())),salience=10)
    def kakao_Enter(self):
        self.declare(Fact(kakao= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(vanilla= W())),salience=10)
    def vanilla_Enter(self):
        self.declare(Fact(vanilla= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(baskot= W())),salience=10)
    def baskot_Enter(self):
        self.declare(Fact(baskot= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(mraba= W())),salience=10)
    def mraba_Enter(self):
        self.declare(Fact(mraba= '0'))
    
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(kahowe= W())),salience=10)
    def kahowe_Enter(self):
        self.declare(Fact(kahowe= '0'))
        
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(krfeh= W())),salience=10)
    def krfeh_Enter(self):
        self.declare(Fact(krfeh= '0'))
    
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(zebdeh= W())),salience=10)
    def zebdeh_Enter(self):
        self.declare(Fact(zebdeh= '0'))
    
    @Rule(Fact('dessert_ingredients_entered'),NOT(Fact(nasle= W())),salience=10)
    def nasle_Enter(self):
        self.declare(Fact(nasle= '0'))
    
     
    # Rules to read user preferences
    @Rule(NOT(Fact(question0=W())),salience=11)
    def choose_menu(self):
        self.declare(Fact(question0 = input('Do you want \n1- dessert \n2- main food\n')))
                      
    @Rule(Fact('IngredientEntered'),salience=9)
    def first_preference(self):
        self.declare(Fact(question1 = input('Choose class of food you want\n1- laban\n2- maraa\n3- hamed\n4- lahem\n5- dajaj\n-6 ajen\n7- makarona\n8- rez\n9- borgul\n'))) 
        
    @Rule(Fact(question1='hamed'))
    def second_preference(self):
        self.declare(Fact(question2 = input('Do you want \n1- mahashi \n2- other\n')))
        
    @Rule(Fact(question1 = 'maraa'))
    def third_preference(self):
        self.declare(Fact(question3 = input('What kind of lahem do you want?\n1- naem \n2- sheaf \n3- kebab\n')))
        
    @Rule(Fact(question1 = 'lahem'))
    def fourth_preference(self):
        self.declare(Fact(question4 = input('Do you want \n1- kebbeh \n2- other\n')))
        
    @Rule(Fact(question1='rez'))
    def fifth_preference(self):
        self.declare(Fact(question5 = input('Do you want rez with \n1- bokouleat  \n2- other ?\n')))
        
    @Rule(Fact(question1='borgul'))
    def sixth_preference(self):
        self.declare(Fact(question6 = input('Do you want borgul with \n1-bokouleat \n2- khadrawat\n')))
    
        
    
        
        
        
        
        
    
    # Facts to Rate choices
    @Rule(
        Fact(question2 = 'other'),
        Fact(rez= 'rez'<<W()),
        Fact(shaieria = 'shaieria'<<W()),
        Fact(semnah = 'semnah'<<W()),
        Fact(hamed= 'hamed'<<W()),
        Fact(batata = 'batata'<<W()),
        Fact(homos = 'homos'<<W()),
        Fact(sheesh = 'sheesh'<<W()),
        Fact(osfor = 'osfor'<<W()),
        Fact(mlokhia = 'mlokhia'<<W()),
        Fact(spanikh = 'spanikh'<<W()),
        Fact(lahem_naem = 'lahem_naem'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer1(self,rez,shaieria,semnah,hamed,batata,homos,sheesh,osfor,mlokhia,spanikh,lahem_naem,availabletime):
        rez = min (float(rez) / 200 , 1.0)
        Shaieria = min (float(shaieria) / 50,1.0)
        Semnah = min (float(semnah) / 20,1.0)
        Hamed = min (float(hamed) / 40,1.0)
        batata = min (float(batata) / 300,1.0)
        Homos = min (float(homos) / 100,1.0)
        Sheesh = min (float(sheesh) / 200,1.0)
        Osfor = min (float(osfor) / 10,1.0)
        Mlokhia = min (float(mlokhia) / 150,1.0)
        Spanikh = min (float(spanikh) / 150,1.0)
        lahem_naem = min (float(lahem_naem) / 150,1.0)
        Availabletime = float(availabletime)
        MlokhiaTime = min(Availabletime /75,1.0)
        SpanikhTime = min(Availabletime/45,1.0)
        MasalaaTime = min(Availabletime/60,1.0)
        MlokiahRate = self.RATE(5,2,rez,Hamed,Semnah,Mlokhia,MlokhiaTime,Shaieria,Sheesh)
        SpanikhRate = self.RATE(5,2,rez,Semnah,Spanikh,Hamed,SpanikhTime,lahem_naem,Shaieria)
        MasalaaRate = self.RATE(6,3,rez,Semnah,batata,Homos,Hamed,MasalaaTime,Shaieria,Sheesh,Osfor)
        mx = max(MlokiahRate,SpanikhRate,MasalaaRate)
        if MlokiahRate == mx:
            print('Cook Mlokhia(ملوخية)')
        elif SpanikhRate == mx:
            print('Cook Spanikh(سبانخ)')
        else :
            print('Cook Masalaa(يخنة حلو)')
            
            
            
    @Rule(
        Fact(question1 = 'laban'),
        Fact(rez= 'rez'<<W()),
        Fact(shaieria = 'shaieria'<<W()),
        Fact(semnah = 'semnah'<<W()),
        Fact(laban= 'laban'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(lahem_sheaf = 'lahem_sheaf'<<W()),
        Fact(kosa = 'kosa'<<W()),
        Fact(lahem_naem = 'lahem_naem'<<W()),
        Fact(zaet = 'zaet'<<W()),
        Fact(taheen = 'taheen'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer2(self,rez,shaieria,semnah,laban,basal,lahem_sheaf,kosa,lahem_naem,zaet,taheen,availabletime):
        rez = min (float(rez) / 200 , 1.0)
        Shaieria = min (float(shaieria) / 50,1.0)
        Semnah = min (float(semnah) / 20,1.0)
        Laban = min (float(laban) / 400,1.0)
        basal = min (float(basal) / 150,1.0)
        Homos = min (float(homos) / 100,1.0)
        lahem_sheaf = min (float(lahem_sheaf) / 200,1.0)
        Kosa = min (float(kosa) / 700,1.0)
        lahem_naem = min (float(lahem_naem) / 200,1.0)
        Zaet = min (float(zaet) / 500,1.0)
        Availabletime = float(availabletime)
        ShakriaTime = min(Availabletime /70,1.0)
        ShiekhTime = min(Availabletime/120,1.0)
        SheshbarakTime = min(Availabletime/55,1.0)
        ShakriaRate = self.RATE(5,2,rez,Semnah,Laban,lahem_sheaf,ShakriaTime,basal,Shaieria)
        ShiekhRate = self.RATE(6,2,rez,Semnah,Laban,Kosa,lahem_naem,ShiekhTime,Zaet,Shaieria)
        SheshbarakRate = self.RATE(3,1,Taheen,lahem_naem,SheshbarakTime,basal)

        mx = max(ShakriaRate,ShiekhRate,SheshbarakRate)
        if ShakriaRate == mx:
            print('Cook Shakria(شاكرية)')
        elif SheshbarakRate == mx:
            print('Cook Sheshbarak(ششبرك)')
        else :
            print('Cook Sheikh Mahshi(شيخ بلبن)')
            
    @Rule(
        Fact(question3 = 'naem'),
        Fact(rez= 'rez'<<W()),
        Fact(shaieria = 'shaieria'<<W()),
        Fact(semnah = 'semnah'<<W()),
        Fact(debes_banadora= 'debes_banadora'<<W()),
        Fact(fasolia = 'fasolia'<<W()),
        Fact(pamia = 'pamia'<<W()),
        Fact(pazzela = 'pazzela'<<W()),
        Fact(batata ='batata'<<W()),
        Fact(jazar = 'jazar'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(homos = 'homos'<<W()),
        Fact(zahra = 'zahra'<<W()),
        Fact(banadora='banadora'<<W()),
        Fact(bathengan='bathengan'<<W()),
        Fact(fasolia_hab='fasolia_hab'<<W()),
        Fact(lahem_kabab = 'lahem_kabab'<<W()),
        Fact(lahem_sheaf = 'lahem_sheaf'<<W()),
        Fact(lahem_naem = 'lahem_naem'<<W()),
        Fact(zaet = 'zaet'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer3(self,rez,shaieria,semnah,debes_banadora,fasolia,pamia,pazzela,batata,zaet,jazar,basal,homos,zahra,banadora,bathengan,fasolia_hab,lahem_kabab,lahem_sheaf,lahem_naem,availabletime):
        rez = min (float(rez) / 200 , 1.0)
        Shaieria = min (float(shaieria) / 50,1.0)
        Semnah = min (float(semnah) / 20,1.0)
        debes_banadora = min (float(debes_banadora) / 50,1.0)
        Fasolia = min (float(fasolia) / 300,1.0)
        Pamia = min (float(pamia) / 300,1.0)
        Pazzela = min (float(pazzela) / 200,1.0)
        batata = min (float(batata) / 300,1.0)
        Jazar = min(float(jazar)/150,1.0)
        Zahra = min(float(zahra)/500,1.0)
        banadora = min(float(banadora)/100,1.0)
        Bathengan = min(float(bathengan)/200,1.0)
        fasolia_hab = min(float(fasolia_hab)/300,1.0)
        basal = min (float(basal) / 150,1.0)
        Homos = min (float(homos) / 100,1.0)
        lahem_sheaf = min (float(lahem_sheaf) / 200,1.0)
        lahem_naem = min (float(lahem_naem) / 200,1.0)
        lahem_kabab = min (float(lahem_kabab) / 200,1.0)
        Zaet = min (float(zaet) / 500,1.0)
        Availabletime = float(availabletime)
        fasoliaTime = min(Availabletime /60,1.0)
        pamiaTime = min(Availabletime/75,1.0)
        pazzelaTime = min(Availabletime/50,1.0)
        kababTime = min(Availabletime/70,1.0)
        zahraTime = min(Availabletime/90,1.0)
        fasoliahabTime = min(Availabletime/90,1.0)
        fasoliaRate = self.RATE(6,1,fasoliaTime,rez,Shaieria,Semnah,debes_banadora,Fasolia,lahem_sheaf)
        pamiaRate = self.RATE(6,1,pamiaTime,rez,Shaieria,Semnah,debes_banadora,Pamia,lahem_sheaf)
        pazzelaRate = self.RATE(8,1,pazzelaTime,rez,Shaieria,Semnah,debes_banadora,Pazzela,batata,Jazar,lahem_sheaf)
        zahraRate = self.RATE(7,1,zahraTime,rez,Shaieria,Semnah,debes_banadora,Zahra,Zaet,lahem_naem)
        fasoliahabRate = self.RATE(6,2,fasoliahabTime,rez,Shaieria,Semnah,debes_banadora,fasolia_hab,Jazar,lahem_sheaf)
        mx = max(fasoliaRate,pamiaRate,pazzelaRate,zahraRate,fasoliahabRate)
        if fasoliaRate == mx:
            print('Cook Fasolia(فاصوليا)')
        elif pamiaRate == mx:
            print('Cook Pamia(بامية)')
        elif pazzelaRate == mx:
            print('Cook Pazzela(بزاليا)')
        elif zahraRate == mx:
            print('Cook Zahra(زهرة و رز)')
        elif fasoliahabRate == mx:
            print('Cook fasolia Hab(فاصوليا حب)')    

    @Rule(
        Fact(question3 = 'sheaf'),
        Fact(rez= 'rez'<<W()),
        Fact(shaieria = 'shaieria'<<W()),
        Fact(semnah = 'semnah'<<W()),
        Fact(debes_banadora= 'debes_banadora'<<W()),
        Fact(batata ='batata'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(homos = 'homos'<<W()),
        Fact(banadora='banadora'<<W()),
        Fact(bathengan='bathengan'<<W()),
        Fact(lahem_sheaf = 'lahem_sheaf'<<W()),
        Fact(availabletime = 'availabletime' << W())
    )  
    def answer4(self,rez,shaieria,semnah,debes_banadora,batata,basal,homos,zahra,banadora,bathengan,lahem_sheaf,availabletime):
        print('Cook Tabakh Roho(طباخ روحو)')
        
               
    
    @Rule(
        Fact(question3 = 'kebab'),
        Fact(rez= 'rez'<<W()),
        Fact(shaieria = 'shaieria'<<W()),
        Fact(semnah = 'semnah'<<W()),
        Fact(debes_banadora= 'debes_banadora'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(lahem_kabab = 'lahem_kabab'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer5(self,rez,shaieria,semnah,debes_banadora,basal,lahem_kabab,availabletime):
            print('Cook Kabab_Hindi(كباب هندي)')
        
    @Rule(
        Fact(question5 = 'other'),
        Fact(kabseh_rez= 'kabseh_rez'<<W()),
        Fact(jazar = 'jazar'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(banadora='banadora'<<W()),
        Fact(zaet = 'zaet'<<W()),
        Fact(dajaj = 'dajaj'<<W()),
        Fact(fahem = 'fahem'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer6(self,kabseh_rez,jazar,basal,banadora,zaet,dajaj,fahem,availabletime):
        Kabseh_rez = min (float(kabseh_rez) / 300 , 1.0)
        basal = min (float(basal) / 150,1.0)        
        Zaet = min (float(zaet) / 80,1.0)
        Jazar = min (float(jazar) / 100,1.0)
        banadora = min (float(banadora) / 100,1.0)
        dajaj = min (float(dajaj) / 300,1.0)
        Fahem = min (float(fahem) / 200,1.0)
        Availabletime = float(availabletime)
        KabsehTime = min(Availabletime/60,1.0)
        MandiTime = min(Availabletime/180,1.0)
        KabsehRate = self.RATE(5,2,Kabseh_rez,basal,Zaet,dajaj,KabsehTime,Jazar,banadora)
        MandiRate = self.RATE(6,2,Kabseh_rez,basal,Zaet,dajaj,Fahem,MandiTime,Jazar,banadora)
        mx = max(KabsehRate,MandiRate)
        if KabsehRate == mx:
            print('Cook Kabseh(كبسة)')
        else :
            print('Cook Mandi(مندي)')  
            
            
        
    @Rule(
        Fact(question5 = 'bokouleat'),
        Fact(rez= 'rez'<<W()),
        Fact(jazar = 'jazar'<<W()),        
        Fact(semnah = 'semnah'<<W()),        
        Fact(pazzela = 'pazzela'<<W()),
        Fact(fool = 'fool'<<W()),
        Fact(lahem_naem='lahem_naem'<<W()),
        Fact(zaet = 'zaet'<<W()),
        Fact(adas = 'adas'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer7(self,rez,pazzela,semnah,fool,lahem_naem,zaet,adas,basal,jazar,availabletime):
        rez = min (float(rez) / 300 , 1.0)
        Semnah = min (float(semnah) / 20,1.0)
        Pazzela = min (float(pazzela) / 180,1.0)
        Jazar = min(float(jazar)/100,1.0)        
        fool = min (float(fool) / 180,1.0)
        lahem_naem = min (float(lahem_naem) / 250,1.0)
        Zaet = min (float(zaet) / 100,1.0)
        Adas = min (float(adas) / 300,1.0)
        basal = min (float(basal) / 300,1.0)
        Availabletime = float(availabletime)
        PazzelaTime = min(Availabletime/30,1.0)
        foolTime = min(Availabletime/30,1.0)
        MojadaraTime = min(Availabletime/50,1.0)
        PazzelaRate = self.RATE(5,1,rez,PazzelaTime,Semnah,Pazzela,lahem_naem,Jazar)
        foolRate = self.RATE(5,1,rez,foolTime,Semnah,fool,lahem_naem,Jazar)
        MojadaraRate = self.RATE(4,2,rez,Semnah,Adas,MojadaraTime,Zaet,basal)
        mx = max(PazzelaRate,foolRate,MojadaraRate)
        if PazzelaRate == mx:
            print('Cook Pazzela(رز ببزاليا)')
        elif foolRate == mx:
            print('Cook fool(رز بفوا)')
        else :
            print('Cook Mojadara(مجدرة)') 
            
        
        
    @Rule(
        Fact(question6 = 'khadrawat'),
        Fact(borgul= 'borgul'<<W()),
        Fact(lahem_naem='lahem_naem'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(banadora='banadora'<<W()),
        Fact(semnah = 'semnah'<<W()),        
        Fact(batata ='batata'<<W()),        
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer8(self,borgul,lahem_naem,semnah,basal,banadora,batata,availabletime):
        Borgul = min (float(borgul) / 300 , 1.0)
        Semnah = min (float(semnah) / 20,1.0)
        lahem_naem = min (float(lahem_naem) / 180,1.0)
        basal = min(float(basal)/100,1.0)        
        banadora = min (float(banadora) / 300,1.0)
        batata = min (float(batata) / 300,1.0)
        Availabletime = float(availabletime)
        banadoraTime = min(Availabletime/30,1.0)
        batataTime = min(Availabletime/40,1.0)
        banadoraRate = self.RATE(4,2,Borgul,Semnah,banadora,banadoraTime,lahem_naem,basal)
        batataRate = self.RATE(4,1,Borgul,Semnah,batata,batataTime,basal)
        mx = max(banadoraRate,batataRate)
        if banadoraRate == mx:
            print('Cook Tommatoes(برغل ببندورة)')
        else :
            print('Cook batataes(برغل ببطاطا)') 
            
    @Rule(
        Fact(question6 = 'bokouleat'),
        Fact(borgul= 'borgul'<<W()),
        Fact(lahem_naem='lahem_naem'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(fool='fool'<<W()),
        Fact(semnah = 'semnah'<<W()),        
        Fact(adas ='adas'<<W()),        
        Fact(zaet = 'zaet'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer9(self,borgul,lahem_naem,semnah,basal,fool,adas,zaet,availabletime):
        Borgul = min (float(borgul) / 300 , 1.0)
        Semnah = min (float(semnah) / 20,1.0)
        lahem_naem = min (float(lahem_naem) / 180,1.0)
        basal = min(float(basal)/200,1.0)        
        fool = min (float(fool) / 300,1.0)
        Adas = min (float(adas) / 300,1.0)
        Zaet = min (float(zaet) / 100,1.0)
        Availabletime = float(availabletime)
        MojadaraTime = min(Availabletime/50,1.0)
        foolTime = min(Availabletime/40,1.0)
        MojadaraRate = self.RATE(4,2,Borgul,Semnah,Adas,MojadaraTime,Zaet,basal)
        foolRate = self.RATE(4,1,Borgul,Semnah,fool,foolTime,lahem_naem)
        mx = max(MojadaraRate,foolRate)
        if MojadaraRate == mx:
            print('Cook Mojadara(مجدرة)')
        else :
            print('Cook Fool(برغل بفول)') 
            
    @Rule(
        Fact(question4 = 'kebbeh'),
        Fact(borgul= 'borgul'<<W()),
        Fact(lahem_habra = 'lahem_habra'<<W()),        
        Fact(taheen='taheen'<<W()),        
        Fact(lahem_naem='lahem_naem'<<W()),
        Fact(basal = 'basal'<<W()),
        Fact(dehnah='dehnah'<<W()),
        Fact(fahem ='fahem'<<W()),        
        Fact(zaet = 'zaet'<<W()),
        Fact(batata ='batata'<<W()),              
        Fact(seleq = 'seleq'<<W()),     
        Fact(lobia = 'lobia'<<W()),   
        Fact(adas = 'adas'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer10(self,borgul,lahem_naem,taheen,lahem_habra,basal,dehnah,fahem,zaet,batata,seleq,lobia,adas,availabletime):
        Borgul = min (float(borgul) / 500 , 1.0)
        Taheen = min (float(taheen) / 500,1.0)
        lahem_naem = min (float(lahem_naem) / 500,1.0)
        basal = min(float(basal)/500,1.0)        
        lahem_habra = min (float(lahem_habra) / 300,1.0)
        Adas = min (float(adas) / 200,1.0)
        Zaet = min (float(zaet) / 300,1.0)
        batata = min (float(batata) / 300,1.0)
        Fahem = min (float(fahem) / 2000,1.0)
        Dehnah = min (float(dehnah) / 300,1.0)
        Lobia = min (float(lobia) / 100,1.0)
        seleq = min (float(seleq) / 200,1.0)
        Availabletime = float(availabletime)
        MaslokTime = min(Availabletime/90,1.0)
        MakliTime = min(Availabletime/110,1.0)
        MashwiTime = min(Availabletime/140,1.0)
        SalesTimes = min(Availabletime/100,1.0)
        MaslokRate = self.RATE(4,1,Borgul,lahem_habra,Dehnah,MaslokTime,basal)
        MakliRate = self.RATE(5,1,Borgul,lahem_habra,lahem_naem,Zaet,MakliTime,basal)
        MashwiRate = self.RATE(5,1,Borgul,lahem_habra,lahem_naem,Fahem,MashwiTime,basal)
        SalesRate = self.RATE(6,2,Borgul,Taheen,Dehnah,seleq,batata,SalesTimes,Lobia,Adas)
        mx = max(MaslokRate,MakliRate,MashwiRate,SalesRate)
        if MaslokRate == mx:
            print('Cook Maslok(كبة مسلوقة)')
        elif MakliRate== mx:
            print('Cook Makli(كبة مقلية)')
        elif MashwiRate== mx:
            print('Cook Mashwi(كبة مشوية)')    
        else :
            print('Cook Sales(صلص)') 
          
           
    @Rule(
        Fact(question8 = 'other'),
        Fact(lahem_naem='lahem_naem'<<W()),
        Fact(zaet = 'zaet'<<W()),
        Fact(banadora= 'banadora'<<W()),
        Fact(bakdones = 'bakdones'<<W()),
        Fact(lahem_burger='lahem_burger'<<W()),
        Fact(bead = 'bead'<<W()), 
        Fact(khas = 'khas'<<W()),
        Fact(jebneh_shedar = 'shader_jebneh'<<W()),
        Fact(lahem_sheaf='lahem_sheaf'<<W()),
        Fact(lahem_kabab = 'lahem_kabab'<<W()),
        Fact(fahem= 'fahem'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer11(self,zaet,lahem_naem,banadora,lahem_burger,bead,khas,shader_jebneh,bakdones,lahem_sheaf,lahem_kabab,fahem,availabletime):
        Zaet = min (float(zaet) / 100,1.0)
        lahem_naem = min (float(lahem_naem) / 500,1.0)
        lahem_sheaf = min (float(lahem_sheaf) / 500,1.0)
        lahem_kabab = min (float(lahem_kabab) / 500 , 1.0)
        Fahem = min (float(fahem) / 2000,1.0)
        banadora = min (float(banadora) / 200 , 1.0)
        lahem_burger = min (float(lahem_burger) / 350,1.0)
        bead = min(float(bead)/100,1.0)        
        Khas = min (float(khas) / 100,1.0)
        Shader_jebneh = min (float(shader_jebneh) / 100,1.0)
        Bakdones = min (float(bakdones) / 100,1.0)
        Availabletime = float(availabletime)
        MamdodaTime = min(Availabletime/50,1.0)
        BurgerTime = min(Availabletime/40,1.0)
        PartsTime = min(Availabletime/90,1.0)
        KababTime = min(Availabletime/90,1.0)
        MamdodaRate = self.RATE(4,1,Zaet,lahem_naem,banadora,MamdodaTime,Bakdones)
        BurgerRate = self.RATE(6,1,lahem_burger,Zaet,banadora,Shader_jebneh,BurgerTime,Khas,bead)
        PartsRate = self.RATE(2,1,lahem_sheaf,Fahem,PartsTime)
        KababRate = self.RATE(2,2,lahem_kabab,Fahem,KababTime,Bakdones)
        mx = max(MamdodaRate,BurgerRate,PartsRate,KababRate)
        if MamdodaRate == mx:
            print('Cook Mamdoda(لحمة بالصينية)')
        elif PartsRate == mx:
            print('Cook (لحمة مشوية)')
        elif KababRate == mx :
            print('Cook Kabab(كباب مشوي)')
        else :
            print('Cook Burger(برغر)') 
    
  
    
            
    @Rule(
        Fact(question1 = 'dajaj'),
        Fact(shawarma='shawarma'<<W()),
        Fact(sheesh = 'sheesh'<<W()),
        Fact(fahem= 'fahem'<<W()),
        Fact(mokhalal ='mokhalal'<<W()),
        Fact(mayonez ='mayonez'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer12(self,shawarma,sheesh,fahem,mokhalal,mayonez,availabletime):
        Shawarma = min (float(shawarma) / 500,1.0)
        Sheesh = min (float(sheesh) / 500 , 1.0)
        Fahem = min (float(fahem) / 2000,1.0)
        Mokhalal = min (float(mokhalal) / 100,1.0)
        Mayonez = min (float(mayonez) / 250,1.0)
        Availabletime = float(availabletime)
        ShawarmaTime = min(Availabletime/45,1.0)
        SheeshTime = min(Availabletime/60,1.0)
        ShawarmaRate = self.RATE(3,2,Shawarma,Fahem,ShawarmaTime,Mayonez,Mokhalal)
        SheeshRate = self.RATE(3,1,Sheesh,Fahem,SheeshTime,Mayonez)
        mx = max(SheeshRate,ShawarmaRate)
        if ShawarmaRate == mx:
            print('Cook Shawarmah(شاورما)')
        else :
            print('Cook Sheesh(شيش طاووق)') 
            
    
    
    @Rule(
        Fact(question1 = 'ajen'),
        Fact(taheen='taheen'<<W()),
        Fact(lahem_naem = 'lahem_naem'<<W()),
        Fact(banadora= 'banadora'<<W()),
        Fact(zaytoon = 'zaytoon'<<W()),
        Fact(basal ='basal'<<W()),
        Fact(jebneh ='jebneh'<<W()),
        Fact(spanikh = 'spanikh'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer13(self,taheen,lahem_naem,banadora,basal,zaytoon,jebneh,spanikh,availabletime):
        Taheen = min (float(taheen) / 500,1.0)
        lahem_naem = min (float(lahem_naem) / 400 , 1.0)
        banadora = min (float(banadora) / 300,1.0)
        zaytoon = min (float(zaytoon) / 400 , 1.0)
        basal = min (float(basal) / 300,1.0)
        Spanikh = min (float(spanikh) / 300,1.0)
        jebneh = min (float(jebneh) / 300,1.0)
        Availabletime = float(availabletime)
        SafehaTime = min(Availabletime/60,1.0)
        SheshbarakTime = min(Availabletime/55,1.0)
        PizzaTime = min(Availabletime/45,1.0)
        SpanikhTime = min(Availabletime/55,1.0)
        SafehaRate = self.RATE(3,1,Taheen,lahem_naem,SafehaTime,banadora)
        PizzaRate = self.RATE(4,1,Taheen,banadora,jebneh,PizzaTime,zaytoon)
        SpanikhRate = self.RATE(3,1,Taheen,Spanikh,SpanikhTime,basal)
        mx = max(SafehaRate,PizzaRate,SpanikhRate)
        if SafehaRate == mx:
            print('Cook Safeha(صفيحة)')
        elif PizzaRate == mx:
            print('Cook Pizza(بيتزا)')
        else :
            print('Cook ٍ Spanikh(سبانخ)')
      
    
        
            
    @Rule(
        Fact(question2 = 'mahashi'),
        Fact(malfof = 'malfof'<<W()),
        Fact(rez= 'rez'<<W()),
        Fact(lahem_naem ='lahem_naem'<<W()),
        Fact(debes_banadora = 'debes_banadora'<<W()),
        Fact(warak_enab = 'warak_enab'<<W()),
        Fact(hamed = 'hamed'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer14(self,malfof,rez,lahem_naem,debes_banadora,warak_enab,hamed,availabletime):
        Malfof = min (float(malfof) / 500 , 1.0)
        rez = min (float(rez) / 300,1.0)
        lahem_naem = min (float(lahem_naem) / 150,1.0)
        debes_banadora = min (float(debes_banadora) / 100,1.0)
        Warak_enab = min (float(warak_enab) / 500,1.0)
        Hamed = min (float(hamed) / 100,1.0)
        Availabletime = float(availabletime)
        MalfofTime = min(Availabletime/65,1.0)
        WarakenabTime = min(Availabletime/80,1.0)
        MalfofRate = self.RATE(3,2,Malfof,rez,MalfofTime,lahem_naem,Hamed)
        WarakenabRate = self.RATE(3,2,Warak_enab,rez,MalfofTime,lahem_naem,Hamed)
        mx = max(MalfofRate,WarakenabRate)
        if MalfofRate == mx:
            print('Cook Malfof(يخنة ملفوف)')  
        else :
            print('Cook Warak Enab (ورق عنب محشي)')
      
    
    @Rule(
        Fact(question1 = 'makarona'),
        Fact(makarona='makarona'<<W()),
        Fact(spaghetti = 'spaghetti'<<W()),
        Fact(bashamel= 'bashamel'<<W()),
        Fact(basal ='basal'<<W()),
        Fact(zaet='zaet'<<W()),
        Fact(debes_banadora = 'debes_banadora'<<W()),
        Fact(lahem_naem = 'lahem_naem'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer15(self,makarona,spaghetti,bashamel,basal,zaet,debes_banadora,lahem_naem,availabletime):
        Makarona = min (float(makarona) / 250,1.0)
        Spaghetti = min (float(spaghetti) / 300 , 1.0)
        Bashamel = min (float(bashamel) / 200,1.0)
        basal = min (float(basal) / 250,1.0)
        Zaet = min (float(zaet) / 100,1.0)
        debes_banadora = min (float(debes_banadora) / 80,1.0)
        lahem_naem = min (float(lahem_naem) / 200,1.0)
        Availabletime = float(availabletime)
        MakaronaTime = min(Availabletime/30,1.0)
        SpaghettiTime = min(Availabletime/40,1.0)
        BashamelTime = min(Availabletime/45,1.0)
        MakaronaRate = self.RATE(2,2,Makarona,MakaronaTime,Zaet,basal)
        SpaghettiRate = self.RATE(4,2,Spaghetti,Zaet,basal,SpaghettiTime,lahem_naem,debes_banadora)
        BashamelRate = self.RATE(3,3,Makarona,Bashamel,BashamelTime,lahem_naem,Zaet,basal)
        mx = max(MakaronaRate,SpaghettiRate,BashamelRate)
        if MakaronaRate == mx:
            print('Cook Makarona(معكرونة)')
        elif SpaghettiRate == mx:
            print('Cook Spaghetti(سباغيتي)')  
        else :
            print('Cook Bashamel (معكرونة بالباشميل)')
                          
    @Rule(Fact('dessert_ingredients_entered'),Fact(question0='dessert'),salience=6)
    def arabic_western_dessert(self):
                self.declare(Fact(question20 = input('What type of dessert do you want?\n1- arabic\n2- western\n')))
                          
    @Rule(Fact('dessert_ingredients_entered'),Fact(question0='dessert'),salience=5)
    def dessert_experience(self):
                self.declare(Fact(question21 = input('What is your experience in making desserts\n1- beginner\n2- good\n')))
        
                          
                    
     
    @Rule(
        Fact(question20='western'),
        Fact(question21='beginner'),
        Fact(taheen='taheen'<<W()),
        Fact(sokar='sokar'<<W()),
        Fact(bead='bead'<<W()),
        Fact(zaet='zaet'<<W()),
        Fact(kakao='kakao'<<W()),
        Fact(haleeb='haleeb'<<W()),
        Fact(vanilla='vanilla'<<W()),
        Fact(baskot='baskot'<<W()),
        Fact(mraba='mraba'<<W()),
        Fact(jebneh_mozarella='jebneh_mozarella'<<W()),
        Fact(availabletime ='availabletime' << W())
         )
    def answer22(self,taheen,sokar,bead,zaet,kakao,haleeb,vanilla,baskot,mraba,jebneh_mozarella,availabletime):
        taheen = min(float(taheen)/400,1.0)
        sokar = min(float(sokar)/60,1.0)
        bead=  min(float(bead)/150,1.0)
        zaet = min(float(zaet)/80,1.0)
        kakao = min(float(kakao)/60,1.0)
        haleeb = min(float(haleeb)/200,1.0)
        vanilla = min(float(vanilla)/25,1.0)
        jebneh_mozarella = min(float(jebneh_mozarella)/300,1.0)
        baskot = min(float(baskot)/400,1.0)
        mraba = min(float(mraba)/100,1.0)
        cake_time = min(float(availabletime)/60,1.0)
        cheese_cake_time = min(float(availabletime)/80,1.0)
        cake_rate = self.RATE(5,3,taheen,sokar,zaet,cake_time,kakao,haleeb,vanilla,bead)
        cheese_cake_rate = self.RATE(6,3,taheen,sokar,baskot,zaet,jebneh_mozarella,cheese_cake_time,mraba,haleeb,bead)
        mx = max(cake_rate,cheese_cake_rate)
        if cake_rate == mx:
            print('Make Chocolate Cake(كاتو بالشوكولا)')
        else:
            print('Make Cheese Cake(كيك بالجبنة)')
    
    
    @Rule(
        Fact(question20='western'),
        Fact(question21='good'),
        Fact(taheen='taheen'<<W()),
        Fact(sokar='sokar'<<W()),
        Fact(bead='bead'<<W()),
        Fact(haleeb='haleeb'<<W()),
        Fact(vanilla='vanilla'<<W()),
        Fact(kahowe='kahowe'<<W()),
        Fact(krfeh='krfeh'<<W()),
        Fact(zebdeh='zebdeh'<<W()),
        Fact(nasle='nasle'<<W()),
        Fact(availabletime = 'availabletime' << W())
         )
    def answer23(self,taheen,sokar,bead,haleeb,vanilla,kahowe,krfeh,zebdeh,nasle,availabletime):
        taheen = min(float(taheen)/200,1.0)
        sokar = min(float(sokar)/40,1.0)
        tiramisu_bead = min(float(bead)/200,1.0)
        cinnabon_bead = min(float(bead)/50,1.0)
        haleeb = min(float(haleeb)/50,1.0)
        vanilla = min(float(vanilla)/10,1.0)
        kahowe = min(float(kahowe)/30,1.0)
        krfeh = min(float(krfeh)/60,1.0)
        zebdeh = min(float(zebdeh)/100,1.0)
        nasle = min(float(nasle)/90,1.0)
        tiramisu_time = min(float(availabletime)/200,1.0)
        cinnabon_time = min(float(availabletime)/100,1.0)
        tiramisu_rate = self.RATE(5,3,taheen,sokar,kahowe,tiramisu_time,tiramisu_bead,vanilla,zebdeh,haleeb)
        cinnabon_rate = self.RATE(5,4,taheen,sokar,cinnabon_bead,krfeh,cinnabon_time,haleeb,vanilla,zebdeh,nasle)
        mx = max(tiramisu_rate,cinnabon_rate)
        if mx == cinnabon_rate:
            print('Make Cinnabon(سينابون)')
        else:
            print('Make tiramisu(تراميسو)')
                          
    @Rule(
        Fact(question20 = 'arabic'),
        Fact(question21 = 'beginner'),
        Fact(sameed = 'sameed'<<W()),
        Fact(sokar= 'sokar'<<W()),
        Fact(laban ='laban'<<W()),
        Fact(joz_hend = 'joz_hend'<<W()),
        Fact(mokasarat = 'mokasarat'<<W()),
        Fact(rez = 'rez'<<W()),
        Fact(haleeb = 'haleeb'<<W()),
        Fact(nashaa = 'nashaa'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer30(self,sameed,sokar,laban,joz_hend,mokasarat,rez,haleeb,nashaa,availabletime):
        sameed = min (float(sameed) / 200 , 1.0)
        sokar = min (float(sokar) / 100,1.0)
        laban = min (float(laban) / 100,1.0)
        joz_hend = min (float(joz_hend) / 100,1.0)
        mokasarat = min (float(mokasarat) / 100,1.0)
        rez = min (float(rez) / 50,1.0)
        haleeb = min (float(haleeb) / 100,1.0)
        nashaa = min (float(nashaa) / 20,1.0)

        Availabletime = float(availabletime)
        rezHaleebTime = min(Availabletime/90,1.0)
        haresaTime = min(Availabletime/60,1.0)
       
        rezHaleebRate = self.RATE(4,1,rez,haleeb,sokar,rezHaleebTime,nashaa)
        haresaRate = self.RATE(4,2,sokar,sameed,joz_hend,haresaTime,laban,mokasarat)
        mx = max(rezHaleebRate,haresaRate)
        if rezHaleebRate == mx:
            print('Make rez haleeb (رز بحليب)')  
        else :
            print('Make Haresa (هريسة)')
            
            
            
    @Rule(
        Fact(question20 = 'arabic'),
        Fact(question21 = 'good'),
        Fact(kenafa = 'kenafa'<<W()),
        Fact(semnah= 'semnah'<<W()),
        Fact(haleeb ='haleeb'<<W()),
        Fact(sokar = 'sokar'<<W()),
        Fact(nashaa = 'nashaa'<<W()),
        Fact(qater = 'qater'<<W()),
        Fact(creama = 'creama'<<W()),
        Fact(sameed = 'sameed'<<W()),
        Fact(jebneh_mozarella = 'jebneh_mozarella'<<W()),
        Fact(qashta = 'qashta'<<W()),
        Fact(mokasarat = 'mokasarat'<<W()),
        Fact(availabletime = 'availabletime' << W()),
    )
    def answer31(self,kenafa,semnah,haleeb,sokar,nashaa,qatar,creama,sameed,jebneh_mozarella,qashta,mokasarat,availabletime):
        kenafa = min (float(kenafa) / 500 , 1.0)
        semnah = min (float(semnah) / 500,1.0)
        haleeb = min (float(haleeb) / 200,1.0)
        sokar = min (float(sokar) / 40,1.0)
        nashaa = min (float(nashaa) / 30,1.0)
        qater = min (float(qater) / 200,1.0)
        creama = min (float(creama) / 100,1.0)
        sameed = min (float(sameed) / 75,1.0)
        jebneh_mozarella = min (float(jebneh_mozarella) / 150,1.0)
        qashta = min (float(qashta) / 100,1.0)
        mokasarat = min (float(mokasarat) / 100,1.0)

        Availabletime = float(availabletime)
        kenafaTime = min(Availabletime/75,1.0)
        halawatJebnehTime = min(Availabletime/90,1.0)
       
        kenafaRate = self.RATE(6,2,kenafa,semnah,haleeb,qater,creama,kenafaTime,nashaa,sokar)
        halawatJebnehTime = self.RATE(5,2,sameed,jebneh_mozarella,qater,qashta,halawatJebnehTime,sokar,nashaa)
        mx = max(kenafaRate,halawatJebnehTime)
        if kenafaRate == mx:
            print('Make Kenafa (كنافة)')  
        else :
            print('Make Halawat Jebneh (حلاوة جبنة)')

# %%
engine = Eng()
engine.reset()
engine.run()
# Out:
# Do you want
# 1- dessert
# 2- main food
# dessert
# **********************************************Ingredients**********************************************************
# bead, baskot,
# creama
#
# jebneh_mozarella, joz_hend,
# haleeb
#
# kakao, kahwe, kenafa
#
# laban,
# mraba, mokasarat
#
# nasle, nashaa,
# qater, qashta
#
# rez,
# sokar, sameed, samneh
#
# taheen,
# vanilla,
# zaet, zebdeh
